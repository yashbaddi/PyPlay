# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/yashbaddi/Downloads/sepdata/data.ipynb Cell 1 line 1
# ----> <a href='vscode-notebook-cell:/Users/yashbaddi/Downloads/sepdata/data.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv('../public_swiggy_data_bangalore_export_2023-11-24_101758.csv')

# %%
df.head(5)
# Out:
#     index       city                              city link       subcity  \
# 0  833439  Bangalore  https://www.swiggy.com/city/bangalore  Geddalahalli
# 1  833440  Bangalore  https://www.swiggy.com/city/bangalore  Geddalahalli
# 2  833441  Bangalore  https://www.swiggy.com/city/bangalore  Geddalahalli
# 3  833442  Bangalore  https://www.swiggy.com/city/bangalore  Geddalahalli
# 4  833443  Bangalore  https://www.swiggy.com/city/bangalore  Geddalahalli
#
#                                         subcity link  restaurant_code  \
# 0  https://www.swiggy.com/city/bangalore/geddalah...           524093
# 1  https://www.swiggy.com/city/bangalore/geddalah...           524093
# 2  https://www.swiggy.com/city/bangalore/geddalah...           524093
# 3  https://www.swiggy.com/city/bangalore/geddalah...           524093
# 4  https://www.swiggy.com/city/bangalore/geddalah...           524093
#
#                       restaurant  rating rating_count   cost  \
# ...

# %%
bangaloreData=df[df['city']=="Bangalore"]

# %%
bangaloreData=bangaloreData[bangaloreData['menu'].notnull()]

# %%
bangaloreData
# Out:
#          index       city                              city link  \
# 0       833439  Bangalore  https://www.swiggy.com/city/bangalore
# 1       833440  Bangalore  https://www.swiggy.com/city/bangalore
# 2       833441  Bangalore  https://www.swiggy.com/city/bangalore
# 3       833442  Bangalore  https://www.swiggy.com/city/bangalore
# 4       833443  Bangalore  https://www.swiggy.com/city/bangalore
# ...        ...        ...                                    ...
# 713339  833434  Bangalore  https://www.swiggy.com/city/bangalore
# 713340  833435  Bangalore  https://www.swiggy.com/city/bangalore
# 713341  833436  Bangalore  https://www.swiggy.com/city/bangalore
# 713342  833437  Bangalore  https://www.swiggy.com/city/bangalore
# 713343  833438  Bangalore  https://www.swiggy.com/city/bangalore
#
#              subcity                                       subcity link  \
# 0       Geddalahalli  https://www.swiggy.com/city/bangalore/geddalah...
# ...

# %%
bangaloreData.columns = [c.lower() for c in bangaloreData.columns]

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://yashbaddi@localhost:5432/foodiefleet2')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/yashbaddi/Downloads/sepdata/data.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/Users/yashbaddi/Downloads/sepdata/data.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> engine = create_engine('postgresql://yashbaddi@localhost:5432/foodiefleet2')
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/sqlalchemy/util/deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# ...

# %%
pip install psycopg2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 kB 5.7 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for psycopg2: filename=psycopg2-2.9.9-cp311-cp311-macosx_12_0_arm64.whl size=144631 sha256=dbcce1b331fa776ead065764d3eb9e23d77537f17844edb6b6d330b57e4d1044
#   Stored in directory: /Users/yashbaddi/Library/Caches/pip/wheels/ab/34/b9/78ebef1b3220b4840ee482461e738566c3c9165d2b5c914f51
# Successfully built psycopg2
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
engine = create_engine('postgresql://yashbaddi@localhost:5432/foodiefleet2')

# %%
bangaloreData.to_sql("swiggy_data_bangalore", engine)
# Out:
# 344
